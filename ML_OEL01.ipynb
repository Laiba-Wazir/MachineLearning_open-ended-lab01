# %% [markdown]
# OEL 01
#
# roll no. = 23-AI-60
#
# dataset = house price

# %% [markdown]
# *   required libraries

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler, LabelEncoder
from sklearn.linear_model import LinearRegression
from sklearn.metrics import r2_score, accuracy_score
from sklearn.svm import SVC

# %matplotlib inline

# %% [markdown]
# ## **EDA**

# %%
train = pd.read_csv('train.csv')   # load trin dataset

# %%
train.head()
# Out:
#    Id  MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 0   1          60       RL         65.0     8450   Pave   NaN      Reg
# 1   2          20       RL         80.0     9600   Pave   NaN      Reg
# 2   3          60       RL         68.0    11250   Pave   NaN      IR1
# 3   4          70       RL         60.0     9550   Pave   NaN      IR1
# 4   5          60       RL         84.0    14260   Pave   NaN      IR1
#
#   LandContour Utilities  ... PoolArea PoolQC Fence MiscFeature MiscVal MoSold  \
# 0         Lvl    AllPub  ...        0    NaN   NaN         NaN       0      2
# 1         Lvl    AllPub  ...        0    NaN   NaN         NaN       0      5
# 2         Lvl    AllPub  ...        0    NaN   NaN         NaN       0      9
# 3         Lvl    AllPub  ...        0    NaN   NaN         NaN       0      2
# 4         Lvl    AllPub  ...        0    NaN   NaN         NaN       0     12
#
#   YrSold  SaleType  SaleCondition  SalePrice
# ...

# %%
test = pd.read_csv('test.csv')  # load test dataset
test
# Out:
#         Id  MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 0     1461          20       RH         80.0    11622   Pave   NaN      Reg
# 1     1462          20       RL         81.0    14267   Pave   NaN      IR1
# 2     1463          60       RL         74.0    13830   Pave   NaN      IR1
# 3     1464          60       RL         78.0     9978   Pave   NaN      IR1
# 4     1465         120       RL         43.0     5005   Pave   NaN      IR1
# ...    ...         ...      ...          ...      ...    ...   ...      ...
# 1454  2915         160       RM         21.0     1936   Pave   NaN      Reg
# 1455  2916         160       RM         21.0     1894   Pave   NaN      Reg
# 1456  2917          20       RL        160.0    20000   Pave   NaN      Reg
# 1457  2918          85       RL         62.0    10441   Pave   NaN      Reg
# 1458  2919          60       RL         74.0     9627   Pave   NaN      Reg
#
# ...

# %%
sample = pd.read_csv('sample_submission.csv')
sample
# Out:
#         Id      SalePrice
# 0     1461  169277.052498
# 1     1462  187758.393989
# 2     1463  183583.683570
# 3     1464  179317.477511
# 4     1465  150730.079977
# ...    ...            ...
# 1454  2915  167081.220949
# 1455  2916  164788.778231
# 1456  2917  219222.423400
# 1457  2918  184924.279659
# 1458  2919  187741.866657
#
# [1459 rows x 2 columns]

# %%
# check missing values
train.isnull().sum()
# Out:
# Id                 0
# MSSubClass         0
# MSZoning           0
# LotFrontage      259
# LotArea            0
#                 ...
# MoSold             0
# YrSold             0
# SaleType           0
# SaleCondition      0
# SalePrice          0
# Length: 81, dtype: int64

# %%
train = train.fillna(train.median(numeric_only=True))
test = test.fillna(test.median(numeric_only=True))

# %%
features = ['GrLivArea', 'OverallQual', 'TotalBsmtSF', 'FullBath', 'YearBuilt']
X_train = train[features]
y_train = train['SalePrice']
X_test = test[features]

# %%
# feature scaling from standard scalar
scaler = StandardScaler()
X_train_scaled = scaler.fit_transform(X_train)
X_test_scaled = scaler.transform(X_test)

# %%
lr = LinearRegression()
lr.fit(X_train_scaled, y_train)

train_pred = lr.predict(X_train_scaled)
r2 = r2_score(y_train, train_pred)
print("R² Score on Training Data:", r2)

test['Predicted_Price'] = lr.predict(X_test_scaled)
# Out:
# R² Score on Training Data: 0.7583658513567064

# %%
# Define bins based on training prices
bins = [0,
        train['SalePrice'].quantile(0.33),
        train['SalePrice'].quantile(0.66),
        train['SalePrice'].max()]

labels = ['Low', 'Medium', 'High']

# Apply to training data
train['Category'] = pd.cut(train['SalePrice'], bins=bins, labels=labels, include_lowest=True)

# Apply same bins to test predictions
test['Predicted_Category'] = pd.cut(test['Predicted_Price'], bins=bins, labels=labels, include_lowest=True)

# %% [markdown]
# o	Use Linear Regression for price prediction.

# %%
y_train_cat = train['Category']
svm = SVC(kernel='rbf', C=1, gamma='scale', random_state=42)
svm.fit(X_train_scaled, y_train_cat)

svm_pred_train = svm.predict(X_train_scaled)
svm_acc = accuracy_score(y_train_cat, svm_pred_train)
print("SVM Accuracy on Training Data:", svm_acc)
# Out:
# SVM Accuracy on Training Data: 0.8239726027397261

# %%
# Predict categories on test set
test['Category_SVM'] = svm.predict(X_test_scaled)

# %%
submission = pd.DataFrame({
    'Id': test['Id'],
    'Predicted_Price': test['Predicted_Price'],
    'Predicted_Category': test['Predicted_Category'],   # from price bin
    'Category_SVM': test['Category_SVM']                # from SVM
})
submission.to_csv('house_price_predictions.csv', index=False)
print("Submission file saved as house_price_predictions.csv")
# Out:
# Submission file saved as house_price_predictions.csv

# %%
print("R² Score on Training Data:", r2)
print("SVM Accuracy:", svm_acc)
# Out:
# R² Score on Training Data: 0.7583658513567064
# SVM Accuracy: 0.8239726027397261
